# %%
import SimpleITK as sitk
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

def displayImage(image):
    plt.imshow(sitk.GetArrayViewFromImage(image))
    plt.axis("off")
    plt.show()

def downloadImage(path):
    reader = sitk.ImageFileReader()
    reader.SetImageIO("NiftiImageIO")
    reader.SetFileName(path)
    image = reader.Execute()
    return image
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
image_1_path = '/Users/josephinebregazzi/Work/summer2023/work/Brain-Scan-Example-Data/Interrsect/images/interrsect-01-005_stripped.nii.gz'
image_2_path = '/Users/josephinebregazzi/Work/summer2023/work/Brain-Scan-Example-Data/Interrsect/images/INTERRSeCT01-005_FollowUp.nii.gz'
# image_dir_path = '/Users/josephinebregazzi/Work/summer2023/work/Brain-Scan-Example-Data/Intersect/images/INTERRSeCT01-005_FollowUp.nii.gz'
# isles_1_path = '/Users/josephinebregazzi/Work/summer2023/work/Isles-22-Flair-Image-Preprocessing/sub-strokecase0002_ses-0001_flair.nii.gz'
# interrsect_1_path = '/home/jbregazzi/Documents/josephine/Datasets/StrokeLesionSegmentation/flair/interrsect/images/INTERRSeCT01-005_FollowUp.nii.gz'

img1 = downloadImage(image_1_path)
img2 = downloadImage(image_2_path)

# %%
displayImage(img1[:,:,24])
displayImage(img2[:,:,24])

# %%
# bet INTERRSeCT01-005_FollowUp.nii.gz interrsect-01-005_stripped.nii.gz -R -f 0.3 -o
original = '/Users/josephinebregazzi/Work/summer2023/work/Brain-Scan-Example-Data/Interrsect/mini-dataset/INTERRSeCT01-019_FollowUp.nii.gz'
new = '/Users/josephinebregazzi/Work/summer2023/work/Brain-Scan-Example-Data/Interrsect/no_skull/interrsect01-019_skull_stripped.nii.gz'

# !bet '/Users/josephinebregazzi/Work/summer2023/work/Brain-Scan-Example-Data/Interrsect/mini-dataset/INTERRSeCT01-019_FollowUp.nii.gz' '/Users/josephinebregazzi/Work/summer2023/work/Brain-Scan-Example-Data/Interrsect/no_skull/interrsect01-019_skull_stripped.nii.gz' -R -f 0.3 -o

# %%
img1_19 = downloadImage(original)
img2_19 = downloadImage(new)

displayImage(img1_19[:,:,24])
displayImage(img2_19[:,:,24])
